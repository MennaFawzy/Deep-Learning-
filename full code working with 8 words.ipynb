# %%
#working with good bounding box
import cv2
import numpy as np
import os

# Creating and Collecting Training Data

mode = 'trainingData'
directory = 'dataSet/' + mode + '/'
minValue = 70

capture = cv2.VideoCapture(0)
interrupt = -1

while True:
    _, frame = capture.read()

    # Simulating mirror Image
    frame = cv2.flip(frame, 1)

    # Getting count of existing images
    count = {
        'tored shiaa': len(os.listdir(directory+"/tored shiaa")),
        'alsalmoalko': len(os.listdir(directory+"/alsalmoalko")),
        'kaifalhal': len(os.listdir(directory+"/kaifalhal")),
        'lawsamht': len(os.listdir(directory+"/lawsamht"))
    }

    # Printing the count of each set on the screen
    cv2.putText(frame, "tored shiaa : " +str(count['tored shiaa']), (10, 60), cv2.FONT_HERSHEY_PLAIN, 1, (0,255,255), 1)
    cv2.putText(frame, "alsalmoalko : " +str(count['alsalmoalko']), (10, 70), cv2.FONT_HERSHEY_PLAIN, 1, (0,255,255), 1)
    cv2.putText(frame, "kaifalhal : " +str(count['kaifalhal']), (10, 80), cv2.FONT_HERSHEY_PLAIN, 1, (0,255,255), 1)
    cv2.putText(frame, "lawsamht : " +str(count['lawsamht']), (10, 90), cv2.FONT_HERSHEY_PLAIN, 1, (0,255,255), 1)

    # Coordinates of the ROI
    x1 = int(0.3*frame.shape[1])
    y1 = 1
    x2 = frame.shape[1]-10
    y2 = int(0.6*frame.shape[1])

    # Drawing the ROI
    # The increment/decrement by 1 is to compensate for the bounding box
    cv2.rectangle(frame, (x1-1, y1-1), (x2+1, y2+1), (255,0,0) ,1)

    # Extracting the ROI
    roi = frame[y1:y2, x1:x2]

    cv2.imshow("Frame", frame)

    # Image Processing
    gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray_roi, (5,5), 2)
    th3 = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)
    ret, test_image = cv2.threshold(th3, minValue, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

    # Output Image after the Image Processing that is used for data collection
    test_image = cv2.resize(test_image, (300,300))
    cv2.imshow("test", test_image)

    # Data Collection
    interrupt = cv2.waitKey(10)
    if interrupt & 0xFF == 27: # esc key
        break
    if interrupt & 0xFF == ord('a'):
        cv2.imwrite(directory+'tored shiaa/'+str(count['tored shiaa'])+'.jpg', gray_roi)
        cv2.imwrite(directory+'tored shiaa/'+str(count['tored shiaa'])+'.jpg', test_image)
    if interrupt & 0xFF == ord('z'):
        cv2.imwrite(directory+'alsalmoalko/'+str(count['alsalmoalko'])+'.jpg', gray_roi)
        cv2.imwrite(directory+'alsalmoalko/'+str(count['alsalmoalko'])+'.jpg', test_image)
    if interrupt & 0xFF == ord('c'):
        cv2.imwrite(directory+'kaifalhal/'+str(count['kaifalhal'])+'.jpg', gray_roi)
        cv2.imwrite(directory+'kaifalhal/'+str(count['kaifalhal'])+'.jpg', test_image)
if interrupt & 0xFF == ord('e'):
    cv2.imwrite(directory+'lawsamht/'+str(count['lawsamht'])+'.jpg', gray_roi)
    cv2.imwrite(directory+'lawsamht/'+str(count['lawsamht'])+'.jpg', test_image)

capture.release()
cv2.destroyAllWindows()

# %%
#working
import cv2
import numpy as np
import os

# Creating and Collecting Training Data

mode = 'trainingData'
directory = 'dataSet/' + mode + '/'
minValue = 70

capture = cv2.VideoCapture(0)
interrupt = -1

while True:
    _, frame = capture.read()

    # Simulating mirror Image
    frame = cv2.flip(frame, 1)

    # Getting count of existing images
    count = {
        'tored shiaa': len(os.listdir(directory+"/tored shiaa")),
        'alsalmoalko': len(os.listdir(directory+"/alsalmoalko")),
        'kaifalhal': len(os.listdir(directory+"/kaifalhal")),
        'lawsamht': len(os.listdir(directory+"/lawsamht"))
    }

    # Printing the count of each set on the screen
    cv2.putText(frame, "tored shiaa : " +str(count['tored shiaa']), (10, 60), cv2.FONT_HERSHEY_PLAIN, 1, (0,255,255), 1)
    cv2.putText(frame, "alsalmoalko : " +str(count['alsalmoalko']), (10, 70), cv2.FONT_HERSHEY_PLAIN, 1, (0,255,255), 1)
    cv2.putText(frame, "kaifalhal : " +str(count['kaifalhal']), (10, 80), cv2.FONT_HERSHEY_PLAIN, 1, (0,255,255), 1)
    cv2.putText(frame, "lawsamht : " +str(count['lawsamht']), (10, 90), cv2.FONT_HERSHEY_PLAIN, 1, (0,255,255), 1)

    # Coordinates of the ROI
    x1 = int(0.5*frame.shape[1])
    y1 = 10
    x2 = frame.shape[1]-10
    y2 = int(0.5*frame.shape[1])

    # Drawing the ROI
    # The increment/decrement by 1 is to compensate for the bounding box
    cv2.rectangle(frame, (x1-1, y1-1), (x2+1, y2+1), (255,0,0) ,1)

    # Extracting the ROI
    roi = frame[y1:y2, x1:x2]

    cv2.imshow("Frame", frame)

    # Image Processing
    gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray_roi, (5,5), 2)
    th3 = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)
    ret, test_image = cv2.threshold(th3, minValue, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

    # Output Image after the Image Processing that is used for data collection
    test_image = cv2.resize(test_image, (300,300))
    cv2.imshow("test", test_image)

    # Data Collection
    interrupt = cv2.waitKey(10)
    if interrupt & 0xFF == 27: # esc key
        break
    if interrupt & 0xFF == ord('a'):
        cv2.imwrite(directory+'tored shiaa/'+str(count['tored shiaa'])+'.jpg', gray_roi)
        cv2.imwrite(directory+'tored shiaa/'+str(count['tored shiaa'])+'.jpg', test_image)
    if interrupt & 0xFF == ord('z'):
        cv2.imwrite(directory+'alsalmoalko/'+str(count['alsalmoalko'])+'.jpg', gray_roi)
        cv2.imwrite(directory+'alsalmoalko/'+str(count['alsalmoalko'])+'.jpg', test_image)
    if interrupt & 0xFF == ord('c'):
        cv2.imwrite(directory+'kaifalhal/'+str(count['kaifalhal'])+'.jpg', gray_roi)
        cv2.imwrite(directory+'kaifalhal/'+str(count['kaifalhal'])+'.jpg', test_image)
if interrupt & 0xFF == ord('e'):
    cv2.imwrite(directory+'lawsamht/'+str(count['lawsamht'])+'.jpg', gray_roi)
    cv2.imwrite(directory+'lawsamht/'+str(count['lawsamht'])+'.jpg', test_image)

capture.release()
cv2.destroyAllWindows()

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(
    'C:\\Users\\Menna Fawzy\\Documents\\college grad proj\\using eminkil code in our project\\dataset\\trainingData',                                
    target_size = (128, 128),
    batch_size = 10,
    color_mode = 'grayscale',                                
    class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(
    'C:\\Users\\Menna Fawzy\\Documents\\college grad proj\\using eminkil code in our project\\dataset\\testingData',
    target_size = (128, 128),                                  
    batch_size = 10,        
    color_mode = 'grayscale',
    class_mode = 'categorical')

num_classes = len(training_set.class_indices)
training_labels = to_categorical(training_set.labels, num_classes=num_classes)
test_labels = to_categorical(test_set.labels, num_classes=num_classes)

classifier = tf.keras.models.Sequential()

classifier.add(tf.keras.layers.Conv2D(filters=32,
                                     kernel_size=3, 
                                     padding="same", 
                                     activation="relu", 
                                     input_shape=[128, 128, 1]))

classifier.add(tf.keras.layers.MaxPool2D(pool_size=2, 
                                         strides=2, 
                                         padding='valid'))

classifier.add(tf.keras.layers.Conv2D(filters=32, 
                                      kernel_size=3, 
                                      padding="same", 
                                      activation="relu"))

classifier.add(tf.keras.layers.MaxPool2D(pool_size=2, 
                                         strides=2, 
                                         padding='valid'))

classifier.add(tf.keras.layers.Flatten())

classifier.add(tf.keras.layers.Dense(units=128, 
                                     activation='relu'))

classifier.add(tf.keras.layers.Dropout(0.40))

classifier.add(tf.keras.layers.Dense(units=96, activation='relu'))

classifier.add(tf.keras.layers.Dropout(0.40))

classifier.add(tf.keras.layers.Dense(units=64, activation='relu'))

classifier.add(tf.keras.layers.Dense(units=num_classes, activation='softmax'))

classifier.compile(optimizer = 'adam', 
                   loss = 'categorical_crossentropy', 
                   metrics = ['accuracy'])


classifier.fit(training_set,
               epochs = 7,
               validation_data = test_set)
# Out:
# Found 8979 images belonging to 8 classes.
# Found 800 images belonging to 8 classes.
# Epoch 1/7
# 898/898 [==============================] - 162s 177ms/step - loss: 0.9087 - accuracy: 0.6650 - val_loss: 0.1067 - val_accuracy: 0.9600
# Epoch 2/7
# 898/898 [==============================] - 157s 175ms/step - loss: 0.2522 - accuracy: 0.9226 - val_loss: 0.0543 - val_accuracy: 0.9812
# Epoch 3/7
# 898/898 [==============================] - 158s 176ms/step - loss: 0.1670 - accuracy: 0.9491 - val_loss: 0.0468 - val_accuracy: 0.9812
# Epoch 4/7
# 898/898 [==============================] - 158s 176ms/step - loss: 0.1299 - accuracy: 0.9607 - val_loss: 0.0135 - val_accuracy: 0.9950
# Epoch 5/7
# 898/898 [==============================] - 158s 176ms/step - loss: 0.1089 - accuracy: 0.9668 - val_loss: 0.0311 - val_accuracy: 0.9925
# Epoch 6/7
# 898/898 [==============================] - 158s 176ms/step - loss: 0.0874 - accuracy: 0.9733 - val_loss: 0.0259 - val_accuracy: 0.9950
# Epoch 7/7
# ...

# %%
model_json = classifier.to_json()
with open("model_new8w.json", "w") as json_file:
    json_file.write(model_json)
print('Model Saved')
classifier.save_weights('model_new8w.h5')
print('Weights saved')
# Out:
# Model Saved
# Weights saved

# %%
# Save the model with a custom name
model_name = '8_words.h5'
classifier.save(model_name)

# %%
#show the output on real time camera
import cv2
import numpy as np
from keras.models import load_model

# Set the minimum threshold value
minValue = 70

# Load the trained model
model = load_model('C:\\Users\\Menna Fawzy\\Documents\\college grad proj\\using eminkil code in our project\\8_words.h5')

# Define the labels for each gesture
labels = ['algamaa','alhamdullah','atlaa bara', 'ayn al makan','lawsamht','shokran','tamam','tored shiaa']

# Start the video capture
capture = cv2.VideoCapture(0)

# Set the width and height of the capture
capture.set(3, 640)
capture.set(4, 480)

while True:
    # Read a frame from the video capture
    ret, frame = capture.read()

    # Flip the frame horizontally to simulate a mirror image
    frame = cv2.flip(frame, 1)

    # Coordinates of the ROI
    x1 = int(0.5 * frame.shape[1])
    y1 = 10
    x2 = frame.shape[1] - 10
    y2 = int(0.5 * frame.shape[1])

    # Drawing the ROI
    # The increment/decrement by 1 is to compensate for the bounding box
    cv2.rectangle(frame, (x1 - 1, y1 - 1), (x2 + 1, y2 + 1), (255, 0, 0), 1)

    # Extracting the ROI
    roi = frame[y1:y2, x1:x2]

    # Image Processing
    gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray_roi, (5, 5), 2)
    th3 = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)
    _, test_image = cv2.threshold(th3, minValue, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    test_image = cv2.resize(test_image, (128, 128))

    # Preprocess the image to be suitable for the model
    test_image = test_image.reshape((1, 128, 128, 1))
    test_image = test_image.astype('float32') / 255

    # Make a prediction using the model
    prediction = model.predict(test_image)

    # Get the predicted label and confidence score
    predicted_label = labels[np.argmax(prediction)]
    confidence_score = np.max(prediction)

    # Display the predicted label and confidence score on the frame
    cv2.putText(frame, f"{predicted_label} ({confidence_score:.2f})", (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    cv2.imshow("Frame", frame)

    # Exit if the 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close all windows
capture.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 26ms/step
# ...
# ...
# 1/1 [==============================] - 0s 32ms/step
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
